# %%
install.packages("tidyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("readr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyr)
library(readr)

# %%
count <- read_delim("/content/final.count_table",
                    delim = "\t", escape_double = FALSE,
                    trim_ws = TRUE)
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 11808 Columns: 1
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): #Compressed Format: groupIndex,abundance. For example 1,6 would mea...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
count
# Out:
#       #Compressed Format: groupIndex,abundance. For example 1,6 would mean the read has an abundance of 6 for group FFP400.
# 1     #1,FFP400\t2,FFP400_2\t3,FFP400_3\t4,FFP400_4\t5,FFP400_5\t6,FFP400_6\t7,FecesDSS3\t8,FecesDSS3_2\t9,FecesDSS3_3\t10,FecesDSS3_4\t11,FecesDSS3_5\t12,FecesNC\t13,FecesNC_2B\t14,NFP400\t15,NFP400_2\t16,NFP400_3\t17,NFP400_5\t18,NFP400_6\t19,NFP400_8
# 2     Representative_Sequence\ttotal\tFFP400\tFFP400_2\tFFP400_3\tFFP400_4\tFFP400_5\tFFP400_6\tFecesDSS3\tFecesDSS3_2\tFecesDSS3_3\tFecesDSS3_4\tFecesDSS3_5\tFecesNC\tFecesNC_2B\tNFP400\tNFP400_2\tNFP400_3\tNFP400_5\tNFP400_6\tNFP400_8
# 3     A00783_1458_HT57CDRX3_1_2232_30454_23891\t1\t7,1
# 4     A01426_770_HMMNJDRX3_1_2244_27615_12148\t1\t4,1
# 5     A01426_771_HMTMJDRX3_1_2101_2266_1626\t1\t9,1
# 6     A01426_771_HMTMJDRX3_1_2143_1298_16454\t1\t17,1
# 7     A01426_771_HMTMJDRX3_1_2104_24117_18552\t3\t18,3
# 8     A01426_770_HMMNJDRX3_1_2227_28664_7983\t1\t11,1
# 9     A01426_771_HMTMJDRX3_1_2148_21703_10019\t1\t12,1
# 10    A01426_771_HMTMJDRX3_1_2154_1542_18067\t1\t10,1
# 11    A01426_771_HMTMJDRX3_1_2127_10059_19038\t1\t14,1
# 12    A01426_770_HMMNJDRX3_1_2224_31873_13322\t23949\t1,1237\t2,3845\t3,605\t4,773\t5,880\t6,1053\t7,918\t8,69\t9,825\t10,2963\t11,792\t12,806\t13,370\t14,551\t15,325\t16,1050\t17,2299\t18,3167\t19,1421
# 13    A01426_771_HMTMJDRX3_1_2138_1226_35149\t1\t16,1
# 14    A01426_771_HMTMJDRX3_1_2159_23936_8469\t1\t16,1
# 15    A01426_771_HMTMJDRX3_1_2246_28474_8625\t1\t8,1
# 16    A01426_771_HMTMJDRX3_1_2246_24596_20823\t1\t12,1
# 17    A01426_770_HMMNJDRX3_1_2120_19777_7028\t1\t11,1
# 18    A01426_771_HMTMJDRX3_1_2174_7862_12477\t6\t2,3\t15,3
# 19    A01426_771_HMTMJDRX3_1_2234_2067_1376\t1\t10,1
# 20    A00783_1458_HT57CDRX3_1_2127_11107_19664\t1\t7,1
# 21    A00783_1458_HT57CDRX3_1_2117_22688_9565\t5\t14,3\t15,2
# 22    A01426_770_HMMNJDRX3_1_2223_18186_2394\t1\t3,1
# 23    A01426_771_HMTMJDRX3_1_2202_17924_19476\t1\t18,1
# 24    A01426_771_HMTMJDRX3_1_2226_28989_32534\t1\t8,1
# 25    A01426_770_HMMNJDRX3_1_2204_31891_36965\t3\t4,3
# 11796 A00783_1458_HT57CDRX3_1_2154_7374_35744
# 11797 A01426_771_HMTMJDRX3_1_2143_20482_12884
# 11798 A01426_771_HMTMJDRX3_1_2211_4969_24408
# 11799 A01426_771_HMTMJDRX3_1_2125_29478_11459
# 11800 A01426_771_HMTMJDRX3_1_2152_5701_10520
# 11801 A00783_1458_HT57CDRX3_1_2175_21043_21465
# 11802 A01426_770_HMMNJDRX3_1_2212_25626_13244
# 11803 A01426_770_HMMNJDRX3_1_2215_26304_3051
# 11804 A00783_1458_HT57CDRX3_1_2117_1434_22545
# 11805 A01426_771_HMTMJDRX3_1_2233_6442_19038
# 11806 A01426_771_HMTMJDRX3_1_2243_7627_29763
#       X2
# 1     Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(99);Lactobacillus(97);
# 2     Bacteria(100);"Bacteroidetes"(100);"Bacteroidia"(96);"Bacteroidales"(96);"Porphyromonadaceae"(87);"Porphyromonadaceae"_unclassified(87);
# 3     Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(95);Lachnospiraceae_unclassified(95);
# 4     Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(99);Lactobacillaceae(98);Lactobacillus(80);
# 5     Bacteria(100);Firmicutes(100);Clostridia(99);Clostridiales(99);Clostridiales_unclassified(99);Clostridiales_unclassified(99);
# 6     Bacteria(100);"Bacteroidetes"(98);"Bacteroidia"(95);"Bacteroidales"(95);"Porphyromonadaceae"(94);"Porphyromonadaceae"_unclassified(94);
# 7     Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(98);Lactobacillaceae(94);Lactobacillaceae_unclassified(94);
# 8     Bacteria(100);"Bacteroidetes"(98);"Bacteroidia"(96);"Bacteroidales"(96);"Bacteroidales"_unclassified(96);"Bacteroidales"_unclassified(96);
# 9     Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(100);Lactobacillus(86);
# 10    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 11    Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(99);Lactobacillaceae(95);Lactobacillus(86);
# 12    Bacteria(100);"Bacteroidetes"(98);"Bacteroidia"(97);"Bacteroidales"(97);"Porphyromonadaceae"(90);"Porphyromonadaceae"_unclassified(90);
# 13    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(85);Lachnospiraceae_unclassified(85);
# 14    Bacteria(100);Firmicutes(100);Bacilli(100);Bacillales(100);Bacillaceae_1(99);Bacillus(97);
# 15    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Eubacteriaceae(100);Anaerofustis(100);
# 16    Bacteria(100);"Bacteroidetes"(100);"Bacteroidia"(94);"Bacteroidales"(94);"Porphyromonadaceae"(94);"Porphyromonadaceae"_unclassified(94);
# 17    Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(95);Lactobacillus(89);
# 18    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 19    Bacteria(100);"Bacteroidetes"(97);"Bacteroidia"(97);"Bacteroidales"(97);"Porphyromonadaceae"(94);"Porphyromonadaceae"_unclassified(94);
# 20    Bacteria(100);"Actinobacteria"(100);Actinobacteria(100);Coriobacteriales(100);Coriobacteriaceae(100);Enterorhabdus(100);
# 21    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(91);Lachnospiraceae_unclassified(91);
# 22    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 23    Bacteria(100);"Actinobacteria"(97);Actinobacteria(97);Coriobacteriales(97);Coriobacteriaceae(97);Olsenella(82);
# 24    Bacteria(100);Firmicutes(97);Clostridia(91);Clostridiales(90);Clostridiales_unclassified(90);Clostridiales_unclassified(90);
# 25    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Dorea(100);
# 26    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(96);Lachnospiraceae_unclassified(96);
# 27    Bacteria(100);Firmicutes(98);Clostridia(94);Clostridiales(93);Clostridiales_unclassified(93);Clostridiales_unclassified(93);
# 28    Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(96);Lachnospiraceae_unclassified(96);
# 29    Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(99);Lactobacillus(95);
# 30    Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(99);Lactobacillus(96);
# ⋮     ⋮
# 11777 Bacteria(100);Firmicutes(97);Clostridia(85);Clostridiales(85);Clostridiales_unclassified(85);Clostridiales_unclassified(85);
# 11778 Bacteria(100);Firmicutes(100);Erysipelotrichia(100);Erysipelotrichales(100);Erysipelotrichaceae(100);Coprobacillus(89);
# 11779 Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(98);Lactobacillaceae(87);Lactobacillaceae_unclassified(87);
# 11780 Bacteria(100);Firmicutes(99);Bacilli(99);Lactobacillales(99);Lactobacillaceae(92);Lactobacillus(84);
# 11781 Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(99);Lactobacillaceae(95);Lactobacillus(87);
# 11782 Bacteria(100);"Bacteroidetes"(99);"Bacteroidia"(95);"Bacteroidales"(95);"Porphyromonadaceae"(95);"Porphyromonadaceae"_unclassified(95);
# 11783 Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(94);Lactobacillus(86);
# 11784 Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(100);Lactobacillus(99);
# 11785 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 11786 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Clostridiales_unclassified(100);Clostridiales_unclassified(100);
# 11787 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Dorea(90);
# 11788 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 11789 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Ruminococcaceae(100);Clostridium_IV(80);
# 11790 Bacteria(100);"Actinobacteria"(100);Actinobacteria(100);Coriobacteriales(100);Coriobacteriaceae(100);Coriobacteriaceae_unclassified(100);
# 11791 Bacteria(100);"Bacteroidetes"(100);"Bacteroidia"(99);"Bacteroidales"(99);"Porphyromonadaceae"(95);"Porphyromonadaceae"_unclassified(95);
# 11792 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Ruminococcaceae(100);Ruminococcaceae_unclassified(100);
# 11793 Bacteria(100);Firmicutes(100);Erysipelotrichia(95);Erysipelotrichales(95);Erysipelotrichaceae(95);Turicibacter(95);
# 11794 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Blautia(84);
# 11795 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 11796 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(96);Lachnospiraceae_unclassified(96);
# 11797 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(98);Lachnospiraceae_unclassified(98);
# 11798 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Ruminococcaceae(100);Clostridium_IV(87);
# 11799 Bacteria(100);Firmicutes(96);Clostridia(96);Clostridiales(93);Lachnospiraceae(91);Lachnospiraceae_unclassified(91);
# 11800 Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(100);Lactobacillus(94);
# 11801 Bacteria(100);Firmicutes(95);Clostridia(82);Clostridiales(82);Clostridiales_unclassified(82);Clostridiales_unclassified(82);
# 11802 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 11803 Bacteria(100);"Bacteroidetes"(99);"Bacteroidia"(97);"Bacteroidales"(97);"Porphyromonadaceae"(96);Barnesiella(90);
# 11804 Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Lachnospiraceae_unclassified(100);
# 11805 Bacteria(99);Bacteria_unclassified(99);Bacteria_unclassified(99);Bacteria_unclassified(99);Bacteria_unclassified(99);Bacteria_unclassified(99);
# 11806 Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Lactobacillaceae(100);Lactobacillaceae_unclassified(100);

# %%
contig_tax <- contig %>% separate(2,sep = ";",into= c("Kingdom","Phylum","Class","Order","Family","Genus","Species"))
contig_tax <- contig_tax[,-8]
head(contig_tax)
# Out:
#   X1                                       Kingdom       Phylum
# 1 A01426_771_HMTMJDRX3_1_2227_2338_13369   Bacteria(100) Firmicutes(100)
# 2 A01426_771_HMTMJDRX3_1_2178_26937_12571  Bacteria(100) "Bacteroidetes"(100)
# 3 A00783_1458_HT57CDRX3_1_2218_23764_20102 Bacteria(100) Firmicutes(100)
# 4 A01426_771_HMTMJDRX3_1_2131_16839_15436  Bacteria(100) Firmicutes(100)
# 5 A01426_771_HMTMJDRX3_1_2105_2618_33270   Bacteria(100) Firmicutes(100)
# 6 A00783_1458_HT57CDRX3_1_2121_22444_10238 Bacteria(100) "Bacteroidetes"(98)
#   Class             Order                Family
# 1 Bacilli(100)      Lactobacillales(100) Lactobacillaceae(99)
# 2 "Bacteroidia"(96) "Bacteroidales"(96)  "Porphyromonadaceae"(87)
# 3 Clostridia(100)   Clostridiales(100)   Lachnospiraceae(95)
# 4 Bacilli(100)      Lactobacillales(99)  Lactobacillaceae(98)
# 5 Clostridia(99)    Clostridiales(99)    Clostridiales_unclassified(99)
# 6 "Bacteroidia"(95) "Bacteroidales"(95)  "Porphyromonadaceae"(94)
#   Genus
# 1 Lactobacillus(97)
# 2 "Porphyromonadaceae"_unclassified(87)
# 3 Lachnospiraceae_unclassified(95)
# 4 Lactobacillus(80)
# 5 Clostridiales_unclassified(99)
# 6 "Porphyromonadaceae"_unclassified(94)

# %%
OTU <- read.delim("/content/final.opti_mcc.0.03.cons.taxonomy")
OTU_tax <- OTU %>% separate(3,sep = ";",into= c("Kingdom","Phylum","Class","Order","Family","Genus","Species"))
OTU_tax <- OTU_tax[,-9]

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("ComplexHeatmap")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.2 (2023-10-31)
#
# Installing package(s) 'BiocVersion', 'ComplexHeatmap'
#
# also installing the dependencies ‘shape’, ‘rjson’, ‘BiocGenerics’, ‘S4Vectors’, ‘iterators’, ‘circlize’, ‘GetoptLong’, ‘clue’, ‘GlobalOptions’, ‘png’, ‘IRanges’, ‘matrixStats’, ‘foreach’, ‘doParallel’
#
#
# Old packages: 'bit', 'curl', 'DBI', 'devtools', 'digest', 'gargle', 'glue',
#   'highr', 'isoband', 'openssl', 'pkgload', 'ragg', 'readr', 'reprex', 'rlang',
#   'roxygen2', 'textshaping', 'uuid', 'whisker', 'withr', 'boot', 'MASS',
#   'Matrix', 'nlme'

# %%
library(ggplot2)
library(ComplexHeatmap)
# Out:
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.18.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================

# %%
# Assuming 'total' is a column in your original data frame 'count'
#count_high <- count[count$total > 100, ]

# Check if 'total' is included in the subset
#if (!"total" %in% colnames(count_high)) {
 # stop("The 'total' column is not present in the subset.")
#}

# Now continue with the rest of your code
#count_high2 <- count_high[, -c(1, 2)]
#count_high2 <- log10(count_high2 + 1)
#count_high2 <- as.matrix(count_high2, ncol = 19)
#rownames(count_high2) <- count$Representative_Sequence[1:100]

#Heatmap(count_high2, row_names_gp = gpar(fontsize = 5))

# %%
OTU_tax_high <- OTU_tax[OTU_tax$Size>100,]

OTU_tax_high$Size <- log10(OTU_tax_high$Size+1)

ggplot(data = OTU_tax_high, aes(x = OTU,y=Size, fill=Class)) +
  geom_bar(aes(), stat="identity", position="stack") #+
  #theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))
ggsave("OTUtax.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
#Rarefaction  Analysis

rarefaction <- read_delim("/content/final.opti_mcc.groups.ave-std.summary",
                          delim = "\t", escape_double = FALSE,
                          trim_ws = TRUE)


rarefaction_coverage <- rarefaction[rarefaction$method == "ave",]

ggplot(data=rarefaction_coverage,aes(x=group,y=coverage))+ geom_col()+
  theme(axis.text.x = element_text(angle=45, vjust=1, hjust=1,size = 8), text=element_text(size=25,  family="TT Times New Roman"))

ggsave("RARe.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 38 Columns: 12
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (2): group, method
# dbl (10): label, nseqs, coverage, sobs, shannon, shannon_lci, shannon_hci, i...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
pcoa <- read_delim("/content/final.opti_mcc.braycurtis.0.03.lt.ave.pcoa.axes",
                                                      delim = "\t", escape_double = FALSE,
                                                      trim_ws = TRUE)


ggplot(data=pcoa,aes(x=axis1,y=axis2,label=group))+
  geom_text(size=3)+theme(axis.text.x = element_text(angle=45, vjust=1, hjust=1,size = 8), text=element_text(size=20,  family="TT Times New Roman"))
ggsave("PCOA.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 20
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (1): group
# dbl (19): axis1, axis2, axis3, axis4, axis5, axis6, axis7, axis8, axis9, axi...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
pcoa <- read_delim("/content/final.opti_mcc.jclass.0.03.lt.ave.pcoa.axes",
                                                      delim = "\t", escape_double = FALSE,
                                                      trim_ws = TRUE)


ggplot(data=pcoa,aes(x=axis1,y=axis2,label=group))+
  geom_text(size=3)+theme(axis.text.x = element_text(angle=45, vjust=1, hjust=1,size = 8), text=element_text(size=20,  family="TT Times New Roman"))
ggsave("PCOA_jclass.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 20
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (1): group
# dbl (19): axis1, axis2, axis3, axis4, axis5, axis6, axis7, axis8, axis9, axi...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
pcoa <- read_delim("/content/final.opti_mcc.braycurtis.0.03.lt.ave.nmds.axes",
                                                      delim = "\t", escape_double = FALSE,
                                                      trim_ws = TRUE)


ggplot(data=pcoa,aes(x=axis1,y=axis2,label=group))+
  geom_text(size=3)+theme(axis.text.x = element_text(angle=45, vjust=1, hjust=1,size = 8), text=element_text(size=20,  family="TT Times New Roman"))
ggsave("NMDS_bray.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): group
# dbl (3): axis1, axis2, axis3
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
pcoa <- read_delim("/content/final.opti_mcc.jclass.0.03.lt.ave.nmds.axes",
                                                      delim = "\t", escape_double = FALSE,
                                                      trim_ws = TRUE)


ggplot(data=pcoa,aes(x=axis1,y=axis2,label=group))+
  geom_text(size=3)+theme(axis.text.x = element_text(angle=45, vjust=1, hjust=1,size = 8), text=element_text(size=20,  family="TT Times New Roman"))
ggsave("NMDS_jclass.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): group
# dbl (3): axis1, axis2, axis3
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("ggtree")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.2 (2023-10-31)
#
# Installing package(s) 'ggtree'
#
# also installing the dependencies ‘gridGraphics’, ‘Rcpp’, ‘ggplotify’, ‘patchwork’, ‘lazyeval’, ‘ape’, ‘aplot’, ‘ggfun’, ‘yulab.utils’, ‘tidytree’, ‘treeio’
#
#
# Old packages: 'pbdZMQ', 'bit', 'curl', 'DBI', 'devtools', 'digest', 'gargle',
#   'glue', 'highr', 'isoband', 'openssl', 'pkgload', 'ragg', 'readr', 'reprex',
#   'rlang', 'roxygen2', 'textshaping', 'uuid', 'whisker', 'withr', 'boot',
#   'MASS', 'Matrix', 'nlme'

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("treeio")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.2 (2023-10-31)
#
# Warning message:
# “package(s) not installed when version(s) same as or greater than current; use
#   `force = TRUE` to re-install: 'treeio'”
# Old packages: 'pbdZMQ', 'bit', 'curl', 'DBI', 'devtools', 'digest', 'gargle',
#   'glue', 'highr', 'isoband', 'openssl', 'pkgload', 'ragg', 'readr', 'reprex',
#   'rlang', 'roxygen2', 'textshaping', 'uuid', 'whisker', 'withr', 'boot',
#   'MASS', 'Matrix', 'nlme'

# %%
library(ggtree)
library(ggplot2)
library(treeio)
# Out:
# ggtree v3.10.0 For help: https://yulab-smu.top/treedata-book/
#
# If you use the ggtree package suite in published research, please cite
# the appropriate paper(s):
#
# Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam.
# ggtree: an R package for visualization and annotation of phylogenetic
# trees with their covariates and other associated data. Methods in
# Ecology and Evolution. 2017, 8(1):28-36. doi:10.1111/2041-210X.12628
#
# S Xu, Z Dai, P Guo, X Fu, S Liu, L Zhou, W Tang, T Feng, M Chen, L
# Zhan, T Wu, E Hu, Y Jiang, X Bo, G Yu. ggtreeExtra: Compact
# visualization of richly annotated phylogenetic data. Molecular Biology
# and Evolution. 2021, 38(9):4039-4042. doi: 10.1093/molbev/msab166
#
# Shuangbin Xu, Lin Li, Xiao Luo, Meijun Chen, Wenli Tang, Li Zhan, Zehan
# Dai, Tommy T. Lam, Yi Guan, Guangchuang Yu. Ggtree: A serialized data
# object for visualization of a phylogenetic tree and annotation data.
# iMeta 2022, 1(4):e56. doi:10.1002/imt2.56
#
#
# Attaching package: ‘ggtree’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# treeio v1.26.0 For help: https://yulab-smu.top/treedata-book/
#
# If you use the ggtree package suite in published research, please cite
# the appropriate paper(s):
#
# LG Wang, TTY Lam, S Xu, Z Dai, L Zhou, T Feng, P Guo, CW Dunn, BR
# Jones, T Bradley, H Zhu, Y Guan, Y Jiang, G Yu. treeio: an R package
# for phylogenetic tree input and output with richly annotated and
# associated data. Molecular Biology and Evolution. 2020, 37(2):599-603.
# doi: 10.1093/molbev/msz240
#
# Guangchuang Yu, David Smith, Huachen Zhu, Yi Guan, Tommy Tsan-Yuk Lam.
# ggtree: an R package for visualization and annotation of phylogenetic
# trees with their covariates and other associated data. Methods in
# Ecology and Evolution. 2017, 8(1):28-36. doi:10.1111/2041-210X.12628
#
# Guangchuang Yu, Tommy Tsan-Yuk Lam, Huachen Zhu, Yi Guan. Two methods
# for mapping and visualizing associated data on phylogeny using ggtree.
# Molecular Biology and Evolution. 2018, 35(12):3041-3043.
# doi:10.1093/molbev/msy194

# %%
#mothurtre <- read.newick(file = "/content/final.opti_mcc.thetayc.0.03.tre")

#normalize <- function(x, na.rm = TRUE) {
 # return((x - min(x)) / (max(x) - min(x)))
#}

#mothurtre$edge.length <- normalize(mothurtre$edge.length - 0.5)

#label_new <- c(mothurtre$tip.label, rep("", 18))

#ggtree(mothurtre)
# Out:
# plot without title

# %% [markdown]
# YOU KNOW

# %%
mothurtre <- read.newick(file = "/content/final.opti_mcc.jclass.0.03.tre")

normalize <- function(x, na.rm = TRUE) {
  return((x - min(x)) / (max(x) - min(x)))
}

mothurtre$edge.length <- normalize(mothurtre$edge.length - 0.5)

label_new <- c(mothurtre$tip.label, rep("", 18))

ggtree(mothurtre)
# Out:
# plot without title

# %%
ggtree(mothurtre) +
  geom_text(
    label = label_new,
    size = 1,
    hjust = -0.2,
    color = "firebrick"
  )
ggsave("Phylo200.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
ggtree(mothurtre, ladderize = FALSE) +
  geom_text(
    label = label_new,
    size = 1,
    hjust = -0.2,
    color = "firebrick"
  )
ggsave("Phylo200.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title
