# %%
library(tidyverse)
library(readxl)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
pcoa <- read_tsv(file="/content/final.opti_mcc.braycurtis.0.03.lt.ave.pcoa.axes")
metadata <- read_excel(path="/content/aliyu_metadata.xlsx")
metadata_pcoa <- inner_join(metadata, pcoa, by=c('sample'='group'))

ggplot(metadata_pcoa, aes(x=axis1, y=axis2, color=dx)) +
	geom_point(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	coord_fixed() +
	labs(title="PCoA of Bray-Curtis Distances Between Stool Samples",
		x="PCo Axis 1",
		y="PCo Axis 2") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("PCoA of Bray-Curtis Distances Between Stool Samples.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 20
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (1): group
# dbl (19): axis1, axis2, axis3, axis4, axis5, axis6, axis7, axis8, axis9, axi...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
pcoa <- read_tsv(file="/content/final.opti_mcc.braycurtis.0.03.lt.ave.nmds.axes")
metadata <- read_excel(path="/content/aliyu_metadata.xlsx")
metadata_pcoa <- inner_join(metadata, pcoa, by=c('sample'='group'))

ggplot(metadata_pcoa, aes(x=axis1, y=axis2, color=dx)) +
	geom_point(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	coord_fixed() +
	labs(title="NMDS of Bray-Curtis Distances Between Stool Samples",
		x="NMDS Axis 1",
		y="NMDS Axis 2") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("NMDS of Bray-Curtis Distances Between Stool Samples.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): group
# dbl (3): axis1, axis2, axis3
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
pcoa <- read_tsv(file="/content/final.opti_mcc.jclass.0.03.lt.ave.pcoa.axes")
metadata <- read_excel(path="/content/aliyu_metadata.xlsx")
metadata_pcoa <- inner_join(metadata, pcoa, by=c('sample'='group'))

ggplot(metadata_pcoa, aes(x=axis1, y=axis2, color=dx)) +
	geom_point(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	coord_fixed() +
	labs(title="PCoA of Jclass Distances Between Stool Samples",
		x="PCo Axis 1",
		y="PCo Axis 2") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("PCoA oJclass.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 20
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr  (1): group
# dbl (19): axis1, axis2, axis3, axis4, axis5, axis6, axis7, axis8, axis9, axi...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
pcoa <- read_tsv(file="/content/final.opti_mcc.jclass.0.03.lt.ave.nmds.axes")
metadata <- read_excel(path="/content/aliyu_metadata.xlsx")
metadata_pcoa <- inner_join(metadata, pcoa, by=c('sample'='group'))

ggplot(metadata_pcoa, aes(x=axis1, y=axis2, color=dx)) +
	geom_point(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	coord_fixed() +
	labs(title="PCoA of Jclass Distances Between Stool Samples",
		x="NMDS Axis 1",
		y="NMDS Axis 2") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("NMDS oJclass.png", width = 10, height = 10, dpi = 300)
# Out:
# Rows: 19 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): group
# dbl (3): axis1, axis2, axis3
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# plot without title

# %%
alpha <- read_tsv(file="/content/final.opti_mcc.groups.ave-std.summary",
		col_types=cols(group = col_character())) %>%
	filter(method=='ave') %>%
	select(group, sobs, shannon, invsimpson, coverage)

meta_alpha <- inner_join(metadata, alpha, by=c('sample'='group'))

# %%
meta_alpha %>%
	group_by(dx) %>%
	summarize(mean=mean(Body_WC), sd=sd(Body_WC))
# Out:
#   dx        mean      sd
# 1 Normal    108.00000 0.000000
# 2 Treated    97.64745 5.317823
# 3 Untreated  86.87041 9.482981

# %%
ggplot(meta_alpha, aes(x=dx, y=Body_WC, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between BWC and groups",
		x=NULL,
		y="Body_WC") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between BWC.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
meta_alpha %>%
	group_by(dx) %>%
	summarize(mean=mean(Colon_length), sd=sd(Colon_length))
# Out:
#   dx        mean     sd
# 1 Normal    9.150000 0.2121320
# 2 Treated   9.508333 0.5434876
# 3 Untreated 6.960000 0.3781534

# %%
ggplot(meta_alpha, aes(x=dx, y=Colon_length, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between Colon_length and groups",
		x=NULL,
		y="Colon_length") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between Colon_length.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
meta_alpha %>%
	group_by(dx) %>%
	summarize(mean=mean(Spleen_weight), sd=sd(Spleen_weight))
# Out:
#   dx        mean  sd
# 1 Normal    55.00 21.21320
# 2 Treated   60.00 30.15113
# 3 Untreated 80.68 29.77099

# %%
ggplot(meta_alpha, aes(x=dx, y=Spleen_weight, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between Spleen_weight and groups",
		x=NULL,
		y="Spleen_weight") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between Spleen_weight.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
meta_alpha %>%
	group_by(dx) %>%
	summarize(mean=mean(Stool_con), sd=sd(Stool_con))
# Out:
#   dx        mean      sd
# 1 Normal    0.0000000 0.0000000
# 2 Treated   0.8703704 0.9449889
# 3 Untreated 2.6666667 0.5443311

# %%
ggplot(meta_alpha, aes(x=dx, y=Stool_con, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between Stool_con and groups",
		x=NULL,
		y="Stool_con") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between Stool_con.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
meta_alpha %>%
	group_by(dx) %>%
	summarize(mean=mean(Fecal_b), sd=sd(Fecal_b))
# Out:
#   dx        mean     sd
# 1 Normal    0.000000 0.0000000
# 2 Treated   1.055556 0.7763334
# 3 Untreated 3.000000 0.5773503

# %%
ggplot(meta_alpha, aes(x=dx, y=Fecal_b, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between Fecal_b and groups",
		x=NULL,
		y="Fecal_b") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between Fecal_b.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
ggplot(meta_alpha, aes(x=dx, y=invsimpson, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between inv and groups",
		x=NULL,
		y="invsimpson") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between invsimpson.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
ggplot(meta_alpha, aes(x=dx, y=shannon, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between shannon and groups",
		x=NULL,
		y="shannon") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between shannon.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %%
ggplot(meta_alpha, aes(x=dx, y=sobs, color=dx)) +
	geom_jitter(shape=19, size=2) +
	scale_color_manual(name=NULL,
		values=c("blue", "red", "black"),
		#breaks=c("normal", "adenoma", "cancer"),
		labels=c("Normal", "Treated", "Untreated")) +
	scale_x_discrete(limits=c("Normal", "Treated", "Untreated"),
		labels=c("Normal", "Treated", "Untreated")) +
	labs(title="Relationship between sobs and groups",
		x=NULL,
		y="sobs") +
	theme_classic() +
  theme(axis.text.x = element_text(angle=45, vjust=5, hjust=10,size = 5), text=element_text(size=18,  family="TT Times New Roman"))

ggsave("Relationship between sobs.png", width = 10, height = 10, dpi = 300)
# Out:
# plot without title

# %% [markdown]
# Taxonomy

# %%
taxonomy <- read_tsv(file="/content/final.opti_mcc.0.03.cons.taxonomy") %>%
		rename_all(tolower)
# Out:
# Rows: 1621 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2): OTU, Taxonomy
# dbl (1): Size
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
string_df <- tibble(
	s = c(
	"Bacteria(100);Firmicutes(100);Clostridia(100);Clostridiales(100);Lachnospiraceae(100);Blautia(95);",
	"Bacteria(100);Firmicutes(100);Bacilli(100);Lactobacillales(100);Streptococcaceae(85);unclassified(100);",
	"Bacteria(100);unclassified(100);unclassified(100);unclassified(100);unclassified(100);unclassified(100);"
	))

# %%
string_df %>%
	mutate(s=str_replace_all(s, "[\\(\\d\\)]", "")) %>%
	mutate(s=str_replace_all(s, "unclassified;", "")) %>%
	mutate(s=str_replace_all(s, "(.*);", "\\1")) %>%
	mutate(s=str_replace_all(s, ".*;(.*)", "\\1"))
# Out:
#   s
# 1 Blautia
# 2 Streptococcaceae
# 3 Bacteria

# %%
taxonomy %>%
	mutate(taxonomy=str_replace_all(string=taxonomy, pattern="\\(100\\)", replacement=""))
# Out:
#      otu     size
bacteria;Firmicutes;Bacilli;Lactobacillales;Lactobacillaceae;Lactobacillus;
# 1593 Bacteria;Firmicutes;Bacilli;Lactobacillales;Lactobacillaceae;Lactobacillus;
# 1594 Bacteria;Firmicutes;Clostridia;Clostridiales;Clostridiales_unclassified;Clostridiales_unclassified;
# 1595 Bacteria;"Bacteroidetes";"Bacteroidia";"Bacteroidales";"Porphyromonadaceae";"Porphyromonadaceae"_unclassified;
# 1596 Bacteria;Firmicutes;Bacilli;Lactobacillales;Lactobacillaceae;Lactobacillus;
# 1597 Bacteria;"Bacteroidetes";"Bacteroidia";"Bacteroidales";"Bacteroidales"_unclassified;"Bacteroidales"_unclassified;
# 1598 Bacteria;Firmicutes;Bacilli;Lactobacillales;Lactobacillaceae;Lactobacillaceae_unclassified;
# 1599 Bacteria;Firmicutes;Clostridia;Clostridiales;Ruminococcaceae;Ruminococcaceae_unclassified;
# 1600 Bacteria;Firmicutes;Clostridia;Clostridiales;Clostridiales_unclassified;Clostridiales_unclassified;
# 1601 Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Lachnospiraceae_unclassified;
# 1602 Bacteria;Firmicutes;Clostridia;Clostridiales;Clostridiales_unclassified;Clostridiales_unclassified;
# 1603 Bacteria;Bacteria_unclassified;Bacteria_unclassified;Bacteria_unclassified;Bacteria_unclassified;Bacteria_unclassified;
# 1604 Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Lachnospiraceae_unclassified;
# 1605 Bacteria;"Verrucomicrobia";Verrucomicrobiae;Verrucomicrobiales;Verrucomicrobiaceae;Akkermansia;
# 1606 Bacteria;Firmicutes;Bacilli;Bacillales;Bacillales_unclassified;Bacillales_unclassified;
# 1607 Bacteria;Firmicutes;Firmicutes_unclassified;Firmicutes_unclassified;Firmicutes_unclassified;Firmicutes_unclassified;
# 1608 Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Lachnospiraceae_unclassified;
# 1609 Bacteria;"Bacteroidetes";"Bacteroidia";"Bacteroidales";Bacteroidaceae;Bacteroides;
# 1610 Bacteria;Firmicutes;Erysipelotrichia;Erysipelotrichales;Erysipelotrichaceae;Erysipelotrichaceae_unclassified;
# 1611 Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Lachnospiraceae_unclassified;
# 1612 Bacteria;Firmicutes;Bacilli;Bacillales;Bacillales_unclassified;Bacillales_unclassified;
# 1613 Bacteria;Firmicutes;Clostridia;Clostridiales;Ruminococcaceae;Ruminococcaceae_unclassified;
# 1614 Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Lachnospiraceae_unclassified;
# 1615 Bacteria;"Actinobacteria";Actinobacteria;Coriobacteriales;Coriobacteriaceae;Collinsella;
# 1616 Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Lachnospiraceae_unclassified;
# 1617 Bacteria;Firmicutes;Clostridia;Clostridia_unclassified;Clostridia_unclassified;Clostridia_unclassified;
# 1618 Bacteria;Firmicutes;Clostridia;Clostridiales;Lachnospiraceae;Lachnospiraceae_unclassified;
# 1619 Bacteria;Firmicutes;Firmicutes_unclassified;Firmicutes_unclassified;Firmicutes_unclassified;Firmicutes_unclassified;
# 1620 Bacteria;Firmicutes;Clostridia;Clostridiales;Clostridiales_unclassified;Clostridiales_unclassified;
# 1621 Bacteria;Firmicutes;Firmicutes_unclassified;Firmicutes_unclassified;Firmicutes_unclassified;Firmicutes_unclassified;

# %%
taxonomy %>%
	mutate(taxonomy=str_replace_all(string=taxonomy, pattern="\\(\\d*\\)", replacement="")) %>%
	filter(str_detect(taxonomy, pattern="\\(")) %>%
	select(taxonomy)
# Out:
#      taxonomy

# %%
library(dplyr)
library(tidyr)

# %%
# Your code
result <- taxonomy %>%
  mutate(taxonomy=str_replace_all(string=taxonomy, pattern="\\(\\d*\\)", replacement="")) %>%
  mutate(taxonomy=str_replace_all(string=taxonomy, pattern=";$", replacement="")) %>%
  separate(taxonomy, into=c("kingdom", "phylum", "class", "order", "family", "genus"), sep=";")

# %%
# Save the result to a CSV file
write.csv(result, "new_taxonomy.tsv", row.names = FALSE)

# %%
read_tsv(file="/content/final.opti_mcc.0.03.cons.taxonomy") %>%
		rename_all(tolower) %>%
		mutate(taxonomy=str_replace_all(string=taxonomy, pattern="\\(\\d*\\)", replacement="")) %>%
		mutate(taxonomy=str_replace_all(string=taxonomy, pattern="unclassified;", replacement="")) %>%
		mutate(taxonomy=str_replace_all(string=taxonomy, pattern=";$", replacement="")) %>%
		mutate(taxonomy=str_replace_all(string=taxonomy, pattern=".*;", replacement=""))
# Out:
# Rows: 1621 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (2
# 1599 Ruminococcaceae_
# 1600 Clostridiales_Clostridiales_
# 1601 Lachnospiraceae_
# 1602 Clostridiales_Clostridiales_
# 1603 Bacteria_Bacteria_Bacteria_Bacteria_Bacteria_
# 1604 Lachnospiraceae_
# 1605 Akkermansia
# 1606 Bacillales_Bacillales_
# 1607 Firmicutes_Firmicutes_Firmicutes_Firmicutes_
# 1608 Lachnospiraceae_
# 1609 Bacteroides
# 1610 Erysipelotrichaceae_
# 1611 Lachnospiraceae_
# 1612 Bacillales_Bacillales_
# 1613 Ruminococcaceae_
# 1614 Lachnospiraceae_
# 1615 Collinsella
# 1616 Lachnospiraceae_
# 1617 Clostridia_Clostridia_Clostridia_
# 1618 Lachnospiraceae_
# 1619 Firmicutes_Firmicutes_Firmicutes_Firmicutes_
# 1620 Clostridiales_Clostridiales_
# 1621 Firmicutes_Firmicutes_Firmicutes_Firmicutes_

# %%
#otu_data <- read_tsv("/content/final.opti_mcc.0.03.subsample.shared")

# %%
otu_data <- read_tsv("/content/final.opti_mcc.0.03.subsample.shared", col_types=cols(Group=col_character())) %>%
	select(-label, -numOtus) %>%
	rename(sample=Group) %>%
	pivot_longer(cols=-sample, names_to="otu", values_to="count")

# %%
otu_data %>% group_by(sample) %>% summarize(n=sum(count)) %>% summary()
# Out:
#     sample                n
#  Length:19          Min.   :98039
#  Class :character   1st Qu.:98039
#  Mode  :character   Median :98039
#                     Mean   :98039
#                     3rd Qu.:98039
#                     Max.   :98039

# %%
otu_data <- read_tsv("/content/final.opti_mcc.0.03.subsample.shared", col_types=cols(Group=col_character())) %>%
	select(-label, -numOtus) %>%
	rename(sample=Group) %>%
	pivot_longer(cols=-sample, names_to="otu", values_to="count") %>%
	mutate(rel_abund=count/98039)

# %%
agg_phylum_data <- inner_join(otu_data, result) %>%
		group_by(sample, phylum) %>%
		summarize(agg_rel_abund=sum(rel_abund))
# Out:
# Joining with `by = join_by(otu)`
# `summarise()` has grouped output by 'sample'. You can override using the
# `.groups` argument.

# %%
metadata <- read_excel(path="/content/aliyu_metadata.xlsx")

# %%
agg_phylum_data <- inner_join(metadata, agg_phylum_data, by=c('sample')) %>%
ungroup() #without this, the sample and phylum columns remain grouped

# %%
agg_phylum_data %>%
		group_by(phylum) %>%
		summarize(median=median(agg_rel_abund)) %>%
		arrange((desc(median)))
# Out:
#    phylum                median
# 1  Firmicutes            0.694947929
# 2  "Bacteroidetes"       0.181162599
# 3  "Verrucomicrobia"     0.035659278
# 4  "Actinobacteria"      0.026591459
# 5  "Proteobacteria"      0.003335407
# 6  TM7                   0.002968207
# 7  Bacteria_unclassified 0.001009802
# 8  "Armatimonadetes"     0.000000000
# 9  "Chloroflexi"         0.000000000
# 10 "Fusobacteria"        0.000000000
# 11 "Planctomycetes"      0.000000000

# %%
top_phyla <- agg_phylum_data %>%
		group_by(phylum) %>%
		summarize(median=median(agg_rel_abund)) %>%
		arrange((desc(median))) %>% # keep this so that the phyla are sorted properly
		top_n(5, median) %>%
		pull(phylum) # use pull to convert the names from a data frame to a vector of names

# %%
agg_phylum_data %>%
	filter(phylum %in% top_phyla) %>%
	ggplot(aes(x=phylum, y=agg_rel_abund, color=dx)) +
		geom_boxplot()
ggsave("taxphltemp.png", width = 10, height = 5, dpi = 300)
# Out:
# plot without title

# %%
agg_phylum_data %>%
	filter(phylum %in% top_phyla) %>%
	mutate(phylum=factor(phylum, levels=top_phyla)) %>%
	ggplot(aes(x=phylum, y=agg_rel_abund, color=dx)) +
		geom_boxplot()
# Out:
# plot without title

# %%
agg_phylum_data %>%
	filter(phylum %in% top_phyla) %>%
	mutate(phylum=factor(phylum, levels=top_phyla)) %>%
	ggplot(aes(x=phylum, y=agg_rel_abund, color=dx)) +
		geom_boxplot() +
		scale_color_manual(name=NULL,
			values=c("black", "blue", "red"),
			#breaks=c("normal", "adenoma", "cancer"),
			labels=c("Normal", "Treated", "Untreated")) +
		scale_y_continuous(breaks=c(0, 0.25, 0.5, 0.75, 1.0), labels=c(0, 25, 50, 75, 100)) +
		labs(title="There are no obvious phylum-level differences between the\ndiagnosis groups",
			x=NULL,
			y="Relative abundance (%)") +
		theme_classic()
ggsave("taxphltemppercent.png", width = 10, height = 5, dpi = 300)
# Out:
# plot without title

# %%
agg_phylum_data %>%
	filter(phylum %in% top_phyla) %>%
	mutate(phylum=factor(phylum, levels=top_phyla)) %>%
	ggplot(aes(x=phylum, y=agg_rel_abund, color=dx)) +
		geom_boxplot() +
		scale_color_manual(name=NULL,
			values=c("black", "blue", "red"),
			#breaks=c("normal", "adenoma", "cancer"),
			labels=c("Normal", "Treated", "Untreated")) +
		labs(title="There are no obvious phylum-level differences between the\ndiagnosis groups",
			x=NULL,
			y="Relative abundance") +
		scale_y_log10() +
		theme_classic()
ggsave("taxphltemplog.png", width = 10, height = 5, dpi = 300)
# Out:
# plot without title

# %% [markdown]
# In this session we focused on phylum-level data. Let's generate a box plot for the five most abundant taxa that are defined as deep as we can classify them. See Activity 2 for the code to generate the taxonomy data. Be careful not to write over your other data frames

# %%
agg_genus_data <- inner_join(otu_data, result) %>%
		group_by(sample, genus) %>%
		summarize(agg_rel_abund=sum(rel_abund))
# Out:
# Joining with `by = join_by(otu)`
# `summarise()` has grouped output by 'sample'. You can override using the
# `.groups` argument.

# %%
agg_genus_data <- inner_join(metadata, agg_genus_data, by=c('sample')) %>%
ungroup() #without this, the sample and phylum columns remain grouped

# %%
agg_genus_data %>%
		group_by(genus) %>%
		summarize(median=median(agg_rel_abund)) %>%
		arrange((desc(median)))
# Out:
#     genus                              median
# 1   Lactobacillus                      0.2720447985
# 2   Lachnospiraceae_unclassified       0.1693815726
# 3   "Porphyromonadaceae"_unclassified  0.0805903773
# 4   Akkermansia                        0.0356592785
# 5   "Prevotellaceae"_unclassified      0.0214914473
# 6   Clostridiales_unclassified         0.0208488459
# 7   Ruminococcaceae_unclassified       0.0200532441
# 8   "Bacteroidales"_unclassified       0.0165546364
# 9   Barnesiella                        0.0158100348
# 10  "Bacteroidetes"_unclassified       0.0134028295
# 11  Ruminococcus                       0.0133110293
# 12  Olsenella                          0.0127704281
# 13  Bacteroides                        0.0122808270
# 14  Enterorhabdus                      0.0088536195
# 15  Firmicutes_unclassified            0.0050388111
# 16  Coriobacteriaceae_unclassified     0.0043044095
# 17  Dorea                              0.0041208091
# 18  Sutterellaceae_unclassified        0.0030294067
# 19  TM7_genus_incertae_sedis           0.0029682065
# 20  Allobaculum                        0.0017646039
# 21  Erysipelotrichaceae_unclassified   0.0016422036
# 22  Alistipes                          0.0014688032
# 23  Lachnospiracea_incertae_sedis      0.0014586032
# 24  Bacteria_unclassified              0.0010098022
# 25  Clostridium_IV                     0.0008976020
# 26  Eubacterium                        0.0006120013
# 27  Erysipelotrichaceae_incertae_sedis 0.0005712013
# 28  Streptococcus                      0.0005712013
# 29  Clostridia_unclassified            0.0004692010
# 30  Enterococcus                       0.0003264007
# ⋮   ⋮                                  ⋮
# 91  Leuconostoc                        0
# 92  Listeria                           0
# 93  Microbacteriaceae_unclassified     0
# 94  Microbispora                       0
# 95  Micromonosporaceae_unclassified    0
# 96  Oceanospirillaceae_unclassified    0
# 97  Paenibacillus                      0
# 98  Paenochrobactrum                   0
# 99  Parabacteroides                    0
# 100 Paracoccus                         0
# 101 Pediococcus                        0
# 102 Prevotella                         0
# 103 Proteus                            0
# 104 Pseudoflavonifractor               0
# 105 Pseudomonadaceae_unclassified      0
# 106 Pseudomonas                        0
# 107 Pseudonocardiaceae_unclassified    0
# 108 Ralstonia                          0
# 109 Rhodocyclaceae_unclassified        0
# 110 Rhodopirellula                     0
# 111 Roseburia                          0
# 112 Saccharopolyspora                  0
# 113 Streptomyces                       0
# 114 Streptomycetaceae_unclassified     0
# 115 Thermobifida                       0
# 116 Thermopolyspora                    0
# 117 Vampirovibrio                      0
# 118 Vibrio                             0
# 119 Weissella                          0
# 120 Xanthomonas                        0

# %%
top_genus <- agg_genus_data %>%
		group_by(genus) %>%
		summarize(median=median(agg_rel_abund)) %>%
		arrange((desc(median))) %>% # keep this so that the phyla are sorted properly
		top_n(5, median) %>%
		pull(genus) # use pull to convert the names from a data frame to a vector of names

# %%
agg_genus_data %>%
	filter(genus %in% top_genus) %>%
	ggplot(aes(x=genus, y=agg_rel_abund, color=dx)) +
		geom_boxplot()
ggsave("taxgenusltemp.png", width = 20, height = 5, dpi = 300)
# Out:
# plot without title

# %%
agg_genus_data %>%
	filter(genus %in% top_genus) %>%
	mutate(genus=factor(genus, levels=top_genus)) %>%
	ggplot(aes(x=genus, y=agg_rel_abund, color=dx)) +
		geom_boxplot() +
		scale_color_manual(name=NULL,
			values=c("black", "blue", "red"),
			#breaks=c("normal", "adenoma", "cancer"),
			labels=c("Normal", "Treated", "Untreated")) +
		scale_y_continuous(breaks=c(0, 0.25, 0.5, 0.75, 1.0), labels=c(0, 25, 50, 75, 100)) +
		labs(title="There are no obvious phylum-level differences between the\ndiagnosis groups",
			x=NULL,
			y="Relative abundance (%)") +
		theme_classic()
ggsave("taxgenustemppercent.png", width = 20, height = 15, dpi = 300)
# Out:
# plot without title

# %% [markdown]
# Hypothesis testing
#
# We've been able to generate strip charts and box plots for the most abundant phyla, but it would be nice to know whether any of these phyla have a significantly different representation across the  groups. We saw in a previous lesson how we can use the Kruskal-Wallis test to test for significance when we have data that are not normally distributed. But how do we do that across groups within a data frame? As we've seen before, we'll group our data by the "phylum" column. Then for each group we'll use the nest/mutate/map/unnest workflow to run kruskal.test as we did in the last lesson.

# %%
library(broom)
library(purrr)

# %%
phylum_tests <- agg_phylum_data %>%
		nest(sample_data = c(-phylum)) %>%
		mutate(test=map(sample_data, ~tidy(kruskal.test(agg_rel_abund~dx, data=.)))) %>%
		unnest(test)

# %% [markdown]
# Of course, because we're doing 17 hypothesis tests, we want to correct our P-values for multiple comparisons, sort the data frame in ascending order by corrected P-value, and then get the names of the phyla with significant differences

# %%
phylum_tests <- agg_phylum_data %>%
		nest(sample_data = c(-phylum)) %>%
		mutate(test=map(sample_data, ~tidy(kruskal.test(agg_rel_abund~dx, data=.)))) %>%
		unnest(test) %>%
		mutate(p.value.adj=p.adjust(p.value, method="BH")) %>%
		arrange(p.value.adj)

sig_phyla <- phylum_tests %>%
		filter(p.value.adj <= 0.05) %>%
		pull(phylum)

# %%
agg_phylum_data %>%
	filter(phylum %in% sig_phyla) %>%
	mutate(phylum=factor(phylum, levels=sig_phyla)) %>%
	mutate(agg_rel_abund=agg_rel_abund+1/21000) %>%
	ggplot(aes(x=phylum, y=agg_rel_abund, color=dx)) +
		geom_hline(yintercept=1/10530, color="gray") +
		geom_boxplot() +
		scale_color_manual(name=NULL,
			values=c("black", "blue", "red"),
			#breaks=c("normal", "adenoma", "cancer"),
			labels=c("Normal", "Treated", "Untreated")) +
		labs(title="Two phyla are significantly associated with disease progression",
			x=NULL,
			y="Relative abundance (%)") +
		scale_y_log10(breaks=c(1e-4, 1e-3, 1e-2, 1e-1, 1), labels=c(1e-2, 1e-1, 1, 10, 100)) +
		theme_classic()
# Out:
# plot without title

# %%
rarefy <- read_tsv(file="/content/final.opti_mcc.groups.rarefaction") %>%
	select(-contains("lci-"), -contains("hci-")) %>%
	pivot_longer(cols=c(-numsampled), names_to='sample', values_to='sobs') %>%
	mutate(sample=str_replace_all(sample, pattern="0.03-", replacement="")) %>%
	drop_na()
# Out:
# Rows: 2435 Columns: 58
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# dbl (58): numsampled, 0.03-FFP400, lci-FFP400, hci-FFP400, 0.03-FFP400_2, lc...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
metadata <- read_excel(path="/content/aliyu_metadata.xlsx")

# %%
metadata_rarefy <- inner_join(metadata, rarefy)
# Out:
# Joining with `by = join_by(sample)`

# %%
set.seed(1) #this makes sure that we all get the same result!
metadata_rarefy_sample <- metadata %>%
	sample_n(10) %>%
	inner_join(., rarefy)

ggplot(metadata_rarefy_sample, aes(x=numsampled, y=sobs, group=sample, color=dx)) +
		geom_line() +
		scale_color_manual(name=NULL,
			values=c("blue", "red", "black"),
			#breaks=c("normal", "adenoma", "cancer"),
			labels=c("Normal", "Treated", "Untreated")) +
		#coord_cartesian(xlim=c(0,20000), ylim=c(0,500)) +
		labs(title="Rarefaction curves",
			x="Number of Sequences Sampled per mouse",
			y="Number of OTUs per sample") +
		theme_classic()
ggsave("PRarefraction.png", width = 10, height = 10, dpi = 300)
# Out:
# Joining with `by = join_by(sample)`
# plot without title
